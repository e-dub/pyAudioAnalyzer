# %% [markdown]
# # Wine Glass

# %% [markdown]
# In this notebook we will go through a basic analysis of audio. First we import the necessary Python library

# %%
import pyAudioAnalysis as paa

# %% [markdown]
# Next we initialize an instance of the sound analyzer and set the audio file to be analyzed.

# %%
SA = paa.SoundAnalyzer()
SA.read("audioFiles/WineGlass.wav")

# %% [markdown]
# The audio file of interest is now played. You should hear an "impact test" in which I hit a wine glass with a knife.

# %%
SA.play()
# Out:
# ALSA lib pcm.c:8545:(snd_pcm_recover) underrun occurred
# ALSA lib pcm.c:8545:(snd_pcm_recover) underrun occurred
# ALSA lib pcm.c:8545:(snd_pcm_recover) underrun occurred
# ALSA lib pcm.c:8545:(snd_pcm_recover) underrun occurred
# ALSA lib pcm.c:8545:(snd_pcm_recover) underrun occurred
# ALSA lib pcm.c:8545:(snd_pcm_recover) underrun occurred

# %% [markdown]
#  Let us now look at the time domain response. You see that the impact occurs at apprxoimately a half a second and the signal dies out by a bit more than four seconds. The peak at nearly seven seconds is from me hitting a key to turn the recording off.

# %%
SA.PlotTimeDomain()

# %% [markdown]
# We will now cut the time domain and plot on the range  [0.45, 5] s.

# %%
SA.PlotTimeDomain(tMin=0.45, tMax=5)

# %% [markdown]
# After finding the proper range by playing with the values, you can cut the data as follows.

# %%
SA.cutData(tMin=0.45, tMax=5)

# %% [markdown]
# We replot the time domain without giving the minimum and maximum time to check the correctness of the cut. Please note that the time will be rezeroed to your minimum time.

# %%
SA.PlotTimeDomain()

# %% [markdown]
# We can now choose two strains (engineering) inbetween which the Young's modulus will be calculated.

# %%
SA.PlotFFT()

# %%
SA.PlotFFT(fMin=500, fMax=2500)

# %%
SA.PlotFFTpyFFTW()

# %%
SA.PlotFFTpyFFTW(fMin=500, fMax=2500)

# %%
SA.PlotSpectrogram()

# %%
SA.PlotSpectrogram(fMin=500, fMax=2500)

# %%
SA.PlotCepstrum()
# Out:
# /usr/local/lib/python3.9/dist-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
